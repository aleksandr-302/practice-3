# %%
x=int(input('введите число '))
if x%5==0 and x%7==0:
  print('11')
if x%5!=0 and x%7!=0:
  print('00')
if x%5==0 and x%7!=0:
  print('01')
if x%5!=0 and x%7==0:
  print('10')
# Out:
# введите число 10
# 01
